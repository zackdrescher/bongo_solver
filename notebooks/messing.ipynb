# %%
from nbutil import ensure_working_project_dir

ensure_working_project_dir()

# %%
from bongo_solver.dictionary import BongoDictionary

dictionary = BongoDictionary.from_text_file("common_words.txt")

# %%
dictionary.words
# Out:
# {'HUMS',
#  'CRAGS',
#  'CAKE',
#  'TIMER',
#  'STICK',
#  'FEVER',
#  'OBEY',
#  'VATS',
#  'STAGS',
#  'DEFOG',
#  'DOLL',
#  'LOBES',
#  'TRUNK',
#  'ZOOM',
#  'FARCE',
#  'GRAMS',
#  'SINCE',
#  'GOAT',
#  'VOTE',
#  'AIR',
#  'NEWSY',
#  'TIDAL',
#  'CARPS',
#  'TRAYS',
#  'WAG',
#  'BRINK',
#  'ZIP',
#  'BONG',
#  'WIND',
#  'FICHE',
#  'NINNY',
#  'STOIC',
#  'WRAPS',
#  'SATED',
#  'ABUZZ',
#  'GYM',
#  'TUB',
#  'HUT',
#  'ROOMY',
#  'THORN',
#  'DUCKS',
#  'FUSES',
#  'COOKS',
#  'SIEGE',
#  'NAMES',
#  'HEAT',
#  'HELM',
#  'HARD',
#  'YUCAS',
#  'VIDEO',
#  'SLIP',
#  'LOVE',
#  'UNDO',
#  'BORAX',
#  'PALED',
#  'SULK',
#  'SMUG',
#  'GUSTS',
#  'ERODE',
#  'HUNTS',
#  'SOAP',
#  'WARMS',
#  'WOODS',
#  'PICKS',
#  'RANDS',
#  'TOM',
#  'DIZZY',
#  'INFO',
#  'PENIS',
#  'DUETS',
#  'ARMS',
#  'ICHOR',
#  'LOAN',
#  'TAKE',
#  'MYRRH',
#  'PRIME',
#  'DOTED',
#  'CORGI',
#  'JACKS',
#  'FAST',
#  'DOOR',
#  'PUKED',
#  'AEGIS',
#  'LEAKY',
#  'BLACK',
#  'MAGMA',
# ...
